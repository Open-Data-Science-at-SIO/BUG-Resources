# %% [markdown]
# 2/8/16 BUG meeting
#
# ---
#
# ### Terry Gaasterland:
# **Intro to flexible command-line biocomputing**
#
# Basic command line intro (cd, ls, mkdir, clear, touch, ...)
#
# #### What about more power- using more cores
# Triton:
# 300-some nodes with 16-24 cores each
#
# e.g.
#
# >ssh tscc-login1.sdsc.edu -l tg
#
# /oasis is a directory with 100 TB "scratch" space-
#
# file can be "renewed":
# > touch
#
# files can be transfered by scp to push or pull data onto triton
#
# Moving data around can be the most cumbersome of
#
# example using triton to blast a dataset of contigs against each other
#
# grep excluding line headers and end-of-line characters
#
# ### biotools
# If there is software of interest, it could be irequested from
#
# module load biotools
# pushd /opt/biotools
#
# module whatis biotools # shows everything that has been installed
#
# includes lots of
# - fastqc
# - qiime1.8.0
# - trimmomatic

# %%
biotools             :                        biotools
biotools             : bedtools 2.20.1        bamtools 2.3.0          biopython 1.62
biotools             : bismark 0.10.1         blast 2.2.29            blat 35
biotools             : bowtie 1.0.0           bowtie2 2.2.3           bwa 0.7.5a
biotools             : bx-python 0.7.2        cufflinks 2.2.0         dendropy 3.12.0
biotools             : edena 3.131028         fastqc 0.10.1           fastx 0.0.14
biotools             : GenomeAnalysisTK 2.8.1 gmap_gsnap 2014_02_20   htseq 0.5.4p5
biotools             : idba-ud 1.1.1          matt 1.00               miRDeep2 0.0.5
biotools             : miso 0.5.2             picard 1.108            plink 1.07
biotools             : pysam 0.7.8pre         qiime 1.8.0             randfold 2.0
biotools             : rsqec 2.4              samtools 0.1.19         soapdenovo r240
biotools             : SOAPsnp v1.03          spades 3.1.0            squid 1.9g
biotools             : stacks 1.20            tophat 2.0.10           trimmomatic 0.32
biotools             : trinity 20131110       velvet 1.2.10           ViennaRNA 2.1.7

# %% [markdown]
# # <font color="red"> Followup after meeting </font>
#
# From Terry's half
# 1. Will send out a link to get a triton login
#    - certain number of cycles for free
#    - is under-utilized by the campus
# 2. Scripps genome center owns several nodes, and therefore thousands of cycles which could be available to you
#
# From Tessa's half
# 1. Where to find program MMT
# 1. Where to find supervisor script
# 1. Where to find the tutorial
# 1. post presentation slides
#
# 1. send another note about the release!

# %% [markdown]
# ### Tessa pierce
# **Make My Transcriptome: an automated pipeline for de novo transcriptomics**
#
# past difficulties
# - installing software
# - running software
#
# Goal: zero-entry analysis through 1) training and programming 2) simpler software
#
# Research: de novo assembly of
#
#
# **Automated via python "SUpERVISOR"** Job manager for parallel
# - lightweight python automation
#    1. command
#    1. dependencies
#    1. targets
#    1. (optional stuff) name, location, # processors, email for updates
#
# Specific application in MMT
# - quick start shows commands, making .csv file
# - tutorial online
# - helper modules
#
# MMT is capable of
# - assembly
# - annotation
# - differential exression
#
# RNAseq data
# Evaluating data quality
#     - length based measures (N50)
#     - Annotation based (e.g. genome completeness)
# Assembly quality
#     - many different means
# Choosing methods- it matters:
#     - saw that Trinity works best
#     - length is not a good metric of number of ORFs, especially with RNA
#         - annotation metrics are better
# How much to sequence
#     - the more complex a sample, the more reads?  Tessa's findings...
#     - digitally normalize large datasets
# pE v SE
#     - No SE!!  bad!!
# Read Length
#     - unclear what is best for RNA dataset
#     - insert length has greater effect
#
# Advantage to using MMT:
#     - Ease of use
#     - Ease of subsitution
#     - Clear starting parameters
#     - Good Logging
